# %%
import cv2
import matplotlib.pyplot as plt
d=cv2.imread(r"C:\Users\hanal\Downloads\i.jpg")
d=cv2.cvtColor(d,cv2.COLOR_BGR2GRAY)
plt.imshow(d,cmap='grey')

# %% [markdown]
# blur

# %%
# b=cv2.GaussianBlur(d,(201,201),0)
import numpy as np
r,c=d.shape
b=np.zeros_like(d)
k= np.array([[1, 2, 1], [2, 4,2], [1, 2, 1]],dtype=np.uint8)/16

for i in range(1, r - 1):
    for j in range(1, c - 1): 
        re = d[i-1:i+2, j-1:j+2]
        n = np.sum(re * k)
        b[i, j] = int(n)

plt.subplot(221)
plt.imshow(d,cmap='grey')
plt.axis('off')
plt.subplot(222)
plt.axis('off')
plt.imshow(b,cmap='grey')
plt.subplot(223)
plt.hist(d)
plt.subplot(224)
plt.hist(b)
# Out:
# (array([[4500.,    0.,    0., ...,    0.,    0.,    0.],
#         [1867.,  263.,  150., ...,    0.,    0.,    0.],
#         [1831.,  297.,  159., ...,    0.,    0.,    0.],
#         ...,
#         [ 744., 1229., 1002., ...,    0.,    0.,    0.],
#         [ 752., 1236., 1004., ...,    0.,    0.,    0.],
#         [4500.,    0.,    0., ...,    0.,    0.,    0.]]),
#  array([  0. ,  17.9,  35.8,  53.7,  71.6,  89.5, 107.4, 125.3, 143.2,
#         161.1, 179. ]),
#  <a list of 3000 BarContainer objects>)

# %% [markdown]
# threshold

# %%
# val,t= cv2.threshold(d, 100, 255, cv2.THRESH_BINARY)

import numpy as np
def thr(y, n):
    # y = np.array(y, dtype=np.uint8)
    r,c = y.shape
   
    for i in range(r):
        for j in range(c):
            if y[i, j] > n:
                y[i, j] = 0
            else:
                y[i, j] = 255
    return y

t=thr(d,100)
d=cv2.imread(r"C:\Users\hanal\Downloads\i.jpg")
d=cv2.cvtColor(d,cv2.COLOR_BGR2GRAY)
plt.subplot(221)
plt.imshow(d,cmap='grey')

plt.axis('off')
plt.subplot(222)
plt.axis('off')
plt.imshow(t,cmap='grey')
plt.subplot(223)
plt.hist(d)
plt.subplot(224)
plt.hist(t)
# Out:
# (array([[8.230e+02, 0.000e+00, 0.000e+00, ..., 0.000e+00, 0.000e+00,
#          3.677e+03],
#         [8.510e+02, 0.000e+00, 0.000e+00, ..., 0.000e+00, 0.000e+00,
#          3.649e+03],
#         [8.680e+02, 0.000e+00, 0.000e+00, ..., 0.000e+00, 0.000e+00,
#          3.632e+03],
#         ...,
#         [4.000e+00, 0.000e+00, 0.000e+00, ..., 0.000e+00, 0.000e+00,
#          4.496e+03],
#         [2.000e+00, 0.000e+00, 0.000e+00, ..., 0.000e+00, 0.000e+00,
#          4.498e+03],
#         [1.000e+00, 0.000e+00, 0.000e+00, ..., 0.000e+00, 0.000e+00,
#          4.499e+03]]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <a list of 3000 BarContainer objects>)

# %% [markdown]
# sharpening

# %%
import numpy as np
k= np.array([[0, -1, 0], [-1, 5, -1], [0, -1, 0]]) 
s= cv2.filter2D(d, -1, k) 

plt.subplot(221)
plt.imshow(d,cmap='grey')
plt.axis('off')
plt.subplot(222)
plt.axis('off')
plt.imshow(s,cmap='grey')
plt.subplot(223)
plt.hist(d)
plt.subplot(224)
plt.hist(s)
# Out:
# (array([[1917.,  355.,  544., ...,    0.,    0.,    0.],
#         [1992.,  256.,  478., ...,    0.,    0.,    0.],
#         [1972.,  287.,  485., ...,    0.,    0.,    0.],
#         ...,
#         [1322., 1406., 1300., ...,    0.,    0.,    0.],
#         [1332., 1391., 1314., ...,    0.,    0.,    0.],
#         [1367., 1434., 1219., ...,    0.,    0.,    0.]]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <a list of 3000 BarContainer objects>)

# %% [markdown]
# fourier transform

# %%
f = np.fft.fft2(d)
fshift = np.fft.fftshift(f)
m = 20*np.log(np.abs(fshift))
plt.subplot(221)
plt.imshow(d,cmap='grey')
plt.axis('off')
plt.subplot(222)
plt.axis('off')
plt.imshow(m,cmap='grey')
plt.subplot(223)
plt.axis('off')
plt.imshow(b,cmap='grey')
f1 = np.fft.fft2(b)
fshift1 = np.fft.fftshift(f1)
m1 = 20*np.log(np.abs(fshift1))
plt.subplot(224)
plt.axis('off')
plt.imshow(m1,cmap='grey')
plt.tight_layout()

# %% [markdown]
# brightness

# %%
i2 = cv2.add(d,100)

plt.subplot(221)
plt.imshow(d,cmap='grey')
plt.axis('off')
plt.subplot(222)
plt.axis('off')
plt.imshow(i2,cmap='grey')
plt.subplot(223)
plt.hist(d)
plt.subplot(224)
plt.hist(i2)
# Out:
# (array([[1505.,  592.,  109., ...,  377.,    0.,    0.],
#         [1458.,  629.,  119., ...,  430.,    0.,    0.],
#         [1437.,  652.,  119., ...,  434.,    0.,    0.],
#         ...,
#         [ 579., 1093.,  668., ...,    0.,    0.,    0.],
#         [ 603., 1097.,  654., ...,    0.,    0.,    0.],
#         [ 625., 1087.,  650., ...,    0.,    0.,    0.]]),
#  array([100. , 115.5, 131. , 146.5, 162. , 177.5, 193. , 208.5, 224. ,
#         239.5, 255. ]),
#  <a list of 3000 BarContainer objects>)

# %%
i3=cv2.add(d,-50)

plt.subplot(221)
plt.imshow(d,cmap='grey')
plt.axis('off')
plt.subplot(222)
plt.axis('off')
plt.imshow(i3,cmap='grey')
plt.subplot(223)
plt.hist(d)
plt.subplot(224)
plt.hist(i3)
# Out:
# (array([[2411.,  580.,  587., ...,    0.,    0.,    0.],
#         [2410.,  571.,  570., ...,    0.,    0.,    0.],
#         [2412.,  553.,  567., ...,    0.,    0.,    0.],
#         ...,
#         [3763.,  391.,  338., ...,    0.,    0.,    0.],
#         [3757.,  398.,  343., ...,    0.,    0.,    0.],
#         [3766.,  388.,  342., ...,    0.,    0.,    0.]]),
#  array([  0. ,  16.1,  32.2,  48.3,  64.4,  80.5,  96.6, 112.7, 128.8,
#         144.9, 161. ]),
#  <a list of 3000 BarContainer objects>)

# %% [markdown]
# negative

# %%
r,c=d.shape
x=np.zeros_like(d)
for i in range(r):
    for j in range(c):
        x[i][j]=255-d[i][j]


plt.subplot(221)
plt.imshow(d,cmap='grey')
plt.axis('off')
plt.subplot(222)
plt.axis('off')
plt.imshow(x,cmap='grey')
plt.subplot(223)
plt.hist(d)
plt.subplot(224)
plt.hist(x)
# Out:
# (array([[   0.,    0.,    0., ...,  218.,  162., 2008.],
#         [   0.,    0.,    0., ...,  208.,  147., 2022.],
#         [   0.,    0.,    0., ...,  210.,  167., 2007.],
#         ...,
#         [   0.,    0.,    0., ..., 1481., 1199., 1002.],
#         [   0.,    0.,    0., ..., 1488., 1196., 1015.],
#         [   0.,    0.,    0., ..., 1457., 1209., 1014.]]),
#  array([ 44. ,  65.1,  86.2, 107.3, 128.4, 149.5, 170.6, 191.7, 212.8,
#         233.9, 255. ]),
#  <a list of 3000 BarContainer objects>)

# %%
r,c=d.shape

# %% [markdown]
# contrast strecthing

# %%
import numpy as np
x1=np.zeros_like(d)
x1=255+((d-np.min(d))/(np.max(d)-np.min(d)))

plt.subplot(221)
plt.imshow(d,cmap='grey')
plt.axis('off')
plt.subplot(222)
plt.axis('off')
plt.imshow(x1,cmap='grey')
plt.subplot(223)
plt.hist(d)
plt.subplot(224)
plt.hist(x1)
# Out:
# (array([[2008.,  162.,  218., ...,    0.,    0.,    0.],
#         [2022.,  147.,  208., ...,    0.,    0.,    0.],
#         [2007.,  167.,  210., ...,    0.,    0.,    0.],
#         ...,
#         [1002., 1199., 1481., ...,    0.,    0.,    0.],
#         [1015., 1196., 1488., ...,    0.,    0.,    0.],
#         [1014., 1209., 1457., ...,    0.,    0.,    0.]]),
#  array([255. , 255.1, 255.2, 255.3, 255.4, 255.5, 255.6, 255.7, 255.8,
#         255.9, 256. ]),
#  <a list of 3000 BarContainer objects>)
